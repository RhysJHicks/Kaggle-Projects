# %%
# Out:
#                               LR    MLP    SVM     DT     RF     NB   k-NN
# Accuracy                   93.04  60.79  88.06  88.19  92.15  91.10  86.67
# Sensitivity                94.50  53.26  92.89  90.09  93.49  92.80  88.62
# Specificity                91.10  70.86  81.60  85.64  90.37  88.83  84.05
# Precision                  93.44  79.42  87.13  89.38  92.86  91.77  88.15
# F1-Score                   93.96  50.58  89.90  89.72  93.16  92.27  88.37
# Negative Predictive Value  92.54  59.21  89.61  86.62  91.25  90.26  84.73
# False Positive Rate         8.90  29.14  18.40  14.36   9.63  11.17  15.95
# False Discovery Rate        6.56  20.58  12.87  10.62   7.14   8.23  11.85
# False Negative Rate         5.50  46.74   7.11   9.91   6.51   7.20  11.38
# Best model per measure:
#
# Accuracy                       -> Best: LR (93.04%)
# Sensitivity                    -> Best: LR (94.50%)
# Specificity                    -> Best: LR (91.10%)
# ...
